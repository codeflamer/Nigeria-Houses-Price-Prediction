# %% [markdown]
# ## Loading Libraties

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import RobustScaler, PowerTransformer, StandardScaler, MinMaxScaler
from sklearn.linear_model import BayesianRidge, Lasso, LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt      
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data Preparation and insights

# %%
df = pd.read_csv("nigeria_houses_data.csv")

# %%
## Dataset has 24326 rows and 8 columns
#Parameters:

#- bedrooms -> number of bedrooms in the houses
#- bathrooms -> number of bathrooms in the houses
#- toilets -> number of toilets 
#- parking_space
#- title -> house type
#- town -> town in which the house is located
#- state -> state within Nigeria in which the house is located and finally
#- price -> the target column.

# %%
df.head()
# Out:
#    bedrooms  bathrooms  toilets  parking_space                 title     town  \
# 0       6.0        5.0      5.0            4.0       Detached Duplex  Mabushi
# 1       4.0        5.0      5.0            4.0     Terraced Duplexes  Katampe
# 2       4.0        5.0      5.0            4.0       Detached Duplex    Lekki
# 3       4.0        4.0      5.0            6.0       Detached Duplex     Ajah
# 4       4.0        4.0      5.0            2.0  Semi Detached Duplex    Lekki
#
#    state        price
# 0  Abuja  450000000.0
# 1  Abuja  800000000.0
# 2  Lagos  120000000.0
# 3  Lagos   40000000.0
# 4  Lagos   75000000.0

# %%
## Lets investigate how many values are missing in the dataset.
df.isnull().sum()
# Apparently no value is missing, So we do not impute here. And move to the next step
# Out:
# bedrooms         0
# bathrooms        0
# toilets          0
# parking_space    0
# title            0
# town             0
# state            0
# price            0
# dtype: int64

# %%
## Lets investigate the bedrooms
#goals
# - How many missig values
# - How can to impute missing values

# %%
df["bedrooms"].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24326 entries, 0 to 24325
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       24326 non-null  float64
#  1   bathrooms      24326 non-null  float64
#  2   toilets        24326 non-null  float64
#  3   parking_space  24326 non-null  float64
#  4   title          24326 non-null  object
#  5   town           24326 non-null  object
#  6   state          24326 non-null  object
#  7   price          24326 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 1.5+ MB

# %%
## Lets Investigate Skewness in the dataset with the numerical columns and zero-inflated columns
numerical_columns = df.select_dtypes(include=['number'])

# %%
## Observing the dataset, there is no significant outlier here

# %%
## Find zero inftated rows
freqTable = (numerical_columns == 0).mean()
# no column as 0 as its column, Then we move to the next stage o meature its skewness

# %%
skewTable = numerical_columns.skew(axis=0).sort_values(ascending=False)

# %%
skewTable
# Out:
# price            135.030477
# parking_space      0.534364
# bedrooms           0.182650
# bathrooms         -0.022984
# toilets           -0.693457
# dtype: float64

# %%
skewTable = numerical_columns.skew(axis=0).sort_values(ascending=False).reset_index()
skewTable.columns = ['feature', 'skewness_value']
plt.figure(figsize=(8,4))
plt.barh(skewTable['feature'],skewTable['skewness_value'],color="red")
plt.xlabel("Skewness Value")
plt.ylabel("feature")
plt.gca().invert_yaxis()
plt.show()

# %%
## It can be observed that Price is significantly skewed, It defies the law of normal distribution which our model is expecting for the dataset to be passed for training.
## The other features have negligible skewness
## It can be ssen that bathroom isnt even skewed
## Different ways to migated skewing will be observed using.
# -log transformation, scaling with squared

# %%
## The histogram distribution of the Price of the first 5000
# numerical_columns.loc[:100,"price"].plot(kind="bar")
# Out:
# <Axes: >

# %%
# # developing a histogram using HISTPLOT, with Price as x variable 
# sns.histplot(data=df, x="price",kde=True)
# plt.title(label   = "Price Distribution")
# plt.xlabel(xlabel = "price") # avoiding using dataset labels
# plt.ylabel(ylabel = "Count")

# %%
# Out:
# 0      450000000.0
# 1      800000000.0
# 2      120000000.0
# 3       40000000.0
# 4       75000000.0
#           ...
# 96      29800000.0
# 97     145000000.0
# 98     150000000.0
# 99      80000000.0
# 100    280000000.0
# Name: price, Length: 101, dtype: float64

# %%
## Now dealing with correlation table
housing_corr = numerical_columns.corr(method="pearson")
housing_corr.loc[:,"price"].sort_values(ascending=False)
# Out:
# price            1.000000
# bedrooms         0.025734
# bathrooms        0.021965
# parking_space    0.018370
# toilets          0.015486
# Name: price, dtype: float64

# %%
categorical_columns = df.select_dtypes(include=['object_'])

# %%
categorical_columns.columns
# Out:
# Index(['title', 'town', 'state'], dtype='object')

# %%
categorical_columns.columns.tolist()
# categorical_columns["title"].unique()
for col in categorical_columns.columns.tolist():
    print(f"{col} - {categorical_columns[col].unique()} - {len(categorical_columns[col].unique())} ")
# Out:
# title - ['Detached Duplex' 'Terraced Duplexes' 'Semi Detached Duplex'
#  'Detached Bungalow' 'Block of Flats' 'Semi Detached Bungalow'
#  'Terraced Bungalow'] - 7
# town - ['Mabushi' 'Katampe' 'Lekki' 'Ajah' 'Epe' 'Lokogoma District' 'Oredo'
#  'Victoria Island (VI)' 'Mowe Ofada' 'Ikeja' 'Ikoyi' 'Magodo' 'Kaura'
#  'Galadimawa' 'Gwarinpa' 'Abeokuta North' 'Lugbe District' 'Ibeju Lekki'
#  'Yaba' 'Sango Ota' 'Ifako-Ijaiye' 'Agege' 'Ikorodu' 'Jahi' 'Ibadan'
#  'Orozo' 'Ifo' 'Owerri North' 'Guzape District' 'Idu Industrial'
#  'Owerri Municipal' 'Isheri North' 'Utako' 'Port Harcourt' 'Kuje' 'Isheri'
#  'Life Camp' 'Ipaja' 'Ado-Odo/Ota' 'Dape' 'Mushin' 'Ejigbo' 'Isolo'
#  'Ojodu' 'Gaduwa' 'Enugu' 'Dakwo' 'Asokoro District' 'Alimosho' 'Sagamu'
#  'Chikun' 'Egbeda' 'Wuye' 'Kubwa' 'Shomolu' 'Ogudu' 'Owerri West' 'Ibafo'
#  'Surulere' 'Obio-Akpor' 'Ayobo' 'Apo' 'Mowe Town' 'Ibadan South-West'
#  'Wuse 2' 'Durumi' 'Simawa' 'Arepo' 'Ikotun' 'Oluyole' 'Maitama District'
#  'Maryland' 'Ido' 'Karsana' 'Wuse' 'Ilorin West' 'Kurudu' 'Karmo'
#  'Abeokuta South' 'KM 46' 'Gbagada' 'Idimu' 'Kaduna South' 'Magboro'
#  'Gudu' 'Kukwaba' 'Mbora (Nbora)' 'Obafemi Owode' 'Jabi' 'Karu' 'Ojo'
#  'Garki' 'Aba' 'Ogijo' 'Asaba' 'Uyo' 'Kosofe' 'Oyigbo' 'Karshi' 'Osogbo'
#  'Kado' 'Ilupeju' 'Afijio' 'Ketu' 'Ado-Ekiti' 'Ibadan North' 'Egor'
#  'Nyanya' 'Ibarapa North' 'Kyami' 'Ojota' 'Dutse' 'Nasarawa' 'Calabar'
#  'Kaduna North' 'Eleme' 'Kafe' 'Oshodi' 'Dakibiyu' 'Amuwo Odofin' 'Ijede'
#  'Bwari' 'Dekina' 'Jos South' 'Agbara-Igbesa' 'Ijaiye' 'Kagini'
#  'Ohaji/Egbema' 'Mpape' 'Apapa' 'Lagos Island' 'Gwagwalada' 'Ijoko'
#  'Diplomatic Zones' 'Akure' 'Ethiope West' 'Badagry' 'Kano' 'Ede South'
#  'Ilorin South' 'Oke-Aro' 'Oke-Odo' 'Ikot Ekpene' 'Kusada' 'Akinyele'
#  'Kabusa' 'Dei-Dei' 'Eket' 'Egbe' 'Udu' 'Ibadan North-East' 'Danja'
#  'Yewa South' 'Warri' 'Duboyi' 'Jikwoyi' 'Oyo West' 'Agbara'
#  'Ovia North-East' 'Yenagoa' 'Central Business District' 'Guzamala'
#  'Lokoja' 'Jos North' 'Orile' 'Wumba' 'Ibadan North-West'
#  'Eko Atlantic City' 'Imota' 'Ikwerre' 'Keffi' 'Ilorin East' 'Uvwie'
#  'Umuahia' 'Ijesha' 'Okene' 'Aniocha South' 'Ijebu Ode' 'Okpe'
#  'Ughelli South' 'Ewekoro' 'Nassarawa' 'Mararaba' 'Uhunmwonde'
#  'Ughelli North' 'Ibeju' 'Abraka' 'Paikoro' 'Ikpoba Okha'] - 189
# state - ['Abuja' 'Lagos' 'Edo' 'Ogun' 'Oyo' 'Imo' 'Anambara' 'Rivers' 'Enugu'
#  'Kaduna' 'Kwara' 'Nasarawa' 'Abia' 'Delta' 'Akwa Ibom' 'Osun' 'Ekiti'
#  'Cross River' 'Kogi' 'Plateau' 'Kano' 'Katsina' 'Bayelsa' 'Borno' 'Niger'] - 25

# %%
pie_state = df.groupby("state").mean().sort_values(by="price",ascending=False)
# Out:
# C:\Users\emryz\AppData\Local\Temp\ipykernel_2980\2174703228.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pie_state = df.groupby("state").mean().sort_values(by="price",ascending=False)

# %%
# Pie chart of the price distribution
labels = pie_state["price"].index.tolist()
values = pie_state["price"].values.tolist()
explode = [0] * len(labels)
explode[0] = 0.1
plt.figure(figsize=(10,10))
plt.pie(values, labels = labels, explode = explode,shadow = False)
plt.legend(loc="best" )
plt.show()

# %% [markdown]
# ## Pie chart for Each State to determine the most expensive regions

# %%
pie_state_town = temp_df.groupby(["state","town"]).mean()
# Out:
# C:\Users\emryz\AppData\Local\Temp\ipykernel_2980\3216399053.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pie_state_town = temp_df.groupby(["state","town"]).mean()

# %%
list_state = temp_df.state.unique().tolist()
for index,state in enumerate(list_state):
    towns_value = pie_state_town.drop(columns=["bedrooms","bathrooms","toilets","parking_space"]).loc[(state)].sort_values(by="price",ascending=False)
    labels = towns_value.index.tolist()
    values = towns_value.price.tolist()
    explode = [0] * len(labels)
    explode[0] = 0.1
    plt.figure(figsize=(10,10))
    plt.pie(values, labels = labels, explode = explode,shadow = False)
    plt.title(f"The Most expensive Towns in : {state}")
    plt.legend(loc="best")
    plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
df.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'toilets', 'parking_space', 'title', 'town',
#        'state', 'price'],
#       dtype='object')

# %%
df.head()
# Out:
#    bedrooms  bathrooms  toilets  parking_space                 title     town  \
# 0       6.0        5.0      5.0            4.0       Detached Duplex  Mabushi
# 1       4.0        5.0      5.0            4.0     Terraced Duplexes  Katampe
# 2       4.0        5.0      5.0            4.0       Detached Duplex    Lekki
# 3       4.0        4.0      5.0            6.0       Detached Duplex     Ajah
# 4       4.0        4.0      5.0            2.0  Semi Detached Duplex    Lekki
#
#    state        price
# 0  Abuja  450000000.0
# 1  Abuja  800000000.0
# 2  Lagos  120000000.0
# 3  Lagos   40000000.0
# 4  Lagos   75000000.0

# %%
## convert categorical labels to integer
temp_df = df.copy()

# %%
df
# Out:
#        bedrooms  bathrooms  toilets  parking_space                 title  \
# 0           6.0        5.0      5.0            4.0       Detached Duplex
# 1           4.0        5.0      5.0            4.0     Terraced Duplexes
# 2           4.0        5.0      5.0            4.0       Detached Duplex
# 3           4.0        4.0      5.0            6.0       Detached Duplex
# 4           4.0        4.0      5.0            2.0  Semi Detached Duplex
# ...         ...        ...      ...            ...                   ...
# 24321       2.0        2.0      2.0            4.0        Block of Flats
# 24322       4.0        5.0      5.0            4.0        Block of Flats
# 24323       4.0        5.0      5.0            4.0       Detached Duplex
# 24324       3.0        4.0      4.0            3.0        Block of Flats
# 24325       4.0        5.0      5.0            4.0       Detached Duplex
#
#                        town  state        price
# 0                   Mabushi  Abuja  450000000.0
# 1                   Katampe  Abuja  800000000.0
# 2                     Lekki  Lagos  120000000.0
# 3                      Ajah  Lagos   40000000.0
# 4                     Lekki  Lagos   75000000.0
# ...                     ...    ...          ...
# 24321                Kabusa  Abuja   15000000.0
# 24322           Ado-Odo/Ota   Ogun   25000000.0
# 24323                 Lekki  Lagos   68000000.0
# 24324  Victoria Island (VI)  Lagos   78000000.0
# 24325                 Lekki  Lagos   65000000.0
#
# [24326 rows x 8 columns]

# %%
## create category labels
categorical_columns.columns.tolist()
# categorical_columns["title"].unique()
category_label = {}
for col in categorical_columns.columns.tolist():
    category_label[col] = {}
    col_values = categorical_columns[col].unique()
    for index, val in enumerate(col_values):
        category_label[col] = {**category_label[col] ,val:index}
category_label
# Out:
# {'title': {'Detached Duplex': 0,
#   'Terraced Duplexes': 1,
#   'Semi Detached Duplex': 2,
#   'Detached Bungalow': 3,
#   'Block of Flats': 4,
#   'Semi Detached Bungalow': 5,
#   'Terraced Bungalow': 6},
#  'town': {'Mabushi': 0,
#   'Katampe': 1,
#   'Lekki': 2,
#   'Ajah': 3,
#   'Epe': 4,
#   'Lokogoma District': 5,
#   'Oredo': 6,
#   'Victoria Island (VI)': 7,
#   'Mowe Ofada': 8,
#   'Ikeja': 9,
#   'Ikoyi': 10,
#   'Magodo': 11,
#   'Kaura': 12,
#   'Galadimawa': 13,
#   'Gwarinpa': 14,
#   'Abeokuta North': 15,
#   'Lugbe District': 16,
#   'Ibeju Lekki': 17,
#   'Yaba': 18,
#   'Sango Ota': 19,
#   'Ifako-Ijaiye': 20,
#   'Agege': 21,
#   'Ikorodu': 22,
#   'Jahi': 23,
#   'Ibadan': 24,
#   'Orozo': 25,
#   'Ifo': 26,
#   'Owerri North': 27,
#   'Guzape District': 28,
#   'Idu Industrial': 29,
#   'Owerri Municipal': 30,
#   'Isheri North': 31,
#   'Utako': 32,
#   'Port Harcourt': 33,
#   'Kuje': 34,
#   'Isheri': 35,
#   'Life Camp': 36,
#   'Ipaja': 37,
#   'Ado-Odo/Ota': 38,
#   'Dape': 39,
#   'Mushin': 40,
#   'Ejigbo': 41,
#   'Isolo': 42,
#   'Ojodu': 43,
#   'Gaduwa': 44,
#   'Enugu': 45,
#   'Dakwo': 46,
#   'Asokoro District': 47,
#   'Alimosho': 48,
#   'Sagamu': 49,
#   'Chikun': 50,
#   'Egbeda': 51,
#   'Wuye': 52,
#   'Kubwa': 53,
#   'Shomolu': 54,
#   'Ogudu': 55,
#   'Owerri West': 56,
#   'Ibafo': 57,
#   'Surulere': 58,
#   'Obio-Akpor': 59,
#   'Ayobo': 60,
#   'Apo': 61,
#   'Mowe Town': 62,
#   'Ibadan South-West': 63,
#   'Wuse 2': 64,
#   'Durumi': 65,
#   'Simawa': 66,
#   'Arepo': 67,
#   'Ikotun': 68,
#   'Oluyole': 69,
#   'Maitama District': 70,
#   'Maryland': 71,
#   'Ido': 72,
#   'Karsana': 73,
#   'Wuse': 74,
#   'Ilorin West': 75,
#   'Kurudu': 76,
#   'Karmo': 77,
#   'Abeokuta South': 78,
#   'KM 46': 79,
#   'Gbagada': 80,
#   'Idimu': 81,
#   'Kaduna South': 82,
#   'Magboro': 83,
#   'Gudu': 84,
#   'Kukwaba': 85,
#   'Mbora (Nbora)': 86,
#   'Obafemi Owode': 87,
#   'Jabi': 88,
#   'Karu': 89,
#   'Ojo': 90,
#   'Garki': 91,
#   'Aba': 92,
#   'Ogijo': 93,
#   'Asaba': 94,
#   'Uyo': 95,
#   'Kosofe': 96,
#   'Oyigbo': 97,
#   'Karshi': 98,
#   'Osogbo': 99,
#   'Kado': 100,
#   'Ilupeju': 101,
#   'Afijio': 102,
#   'Ketu': 103,
#   'Ado-Ekiti': 104,
#   'Ibadan North': 105,
#   'Egor': 106,
#   'Nyanya': 107,
#   'Ibarapa North': 108,
#   'Kyami': 109,
#   'Ojota': 110,
#   'Dutse': 111,
#   'Nasarawa': 112,
#   'Calabar': 113,
#   'Kaduna North': 114,
#   'Eleme': 115,
#   'Kafe': 116,
#   'Oshodi': 117,
#   'Dakibiyu': 118,
#   'Amuwo Odofin': 119,
#   'Ijede': 120,
#   'Bwari': 121,
#   'Dekina': 122,
#   'Jos South': 123,
#   'Agbara-Igbesa': 124,
#   'Ijaiye': 125,
#   'Kagini': 126,
#   'Ohaji/Egbema': 127,
#   'Mpape': 128,
#   'Apapa': 129,
#   'Lagos Island': 130,
#   'Gwagwalada': 131,
#   'Ijoko': 132,
#   'Diplomatic Zones': 133,
#   'Akure': 134,
#   'Ethiope West': 135,
#   'Badagry': 136,
#   'Kano': 137,
#   'Ede South': 138,
#   'Ilorin South': 139,
#   'Oke-Aro': 140,
#   'Oke-Odo': 141,
#   'Ikot Ekpene': 142,
#   'Kusada': 143,
#   'Akinyele': 144,
#   'Kabusa': 145,
#   'Dei-Dei': 146,
#   'Eket': 147,
#   'Egbe': 148,
#   'Udu': 149,
#   'Ibadan North-East': 150,
#   'Danja': 151,
#   'Yewa South': 152,
#   'Warri': 153,
#   'Duboyi': 154,
#   'Jikwoyi': 155,
#   'Oyo West': 156,
#   'Agbara': 157,
#   'Ovia North-East': 158,
#   'Yenagoa': 159,
#   'Central Business District': 160,
#   'Guzamala': 161,
#   'Lokoja': 162,
#   'Jos North': 163,
#   'Orile': 164,
#   'Wumba': 165,
#   'Ibadan North-West': 166,
#   'Eko Atlantic City': 167,
#   'Imota': 168,
#   'Ikwerre': 169,
#   'Keffi': 170,
#   'Ilorin East': 171,
#   'Uvwie': 172,
#   'Umuahia': 173,
#   'Ijesha': 174,
#   'Okene': 175,
#   'Aniocha South': 176,
#   'Ijebu Ode': 177,
#   'Okpe': 178,
#   'Ughelli South': 179,
#   'Ewekoro': 180,
#   'Nassarawa': 181,
#   'Mararaba': 182,
#   'Uhunmwonde': 183,
#   'Ughelli North': 184,
#   'Ibeju': 185,
#   'Abraka': 186,
#   'Paikoro': 187,
#   'Ikpoba Okha': 188},
#  'state': {'Abuja': 0,
#   'Lagos': 1,
#   'Edo': 2,
#   'Ogun': 3,
#   'Oyo': 4,
#   'Imo': 5,
#   'Anambara': 6,
#   'Rivers': 7,
#   'Enugu': 8,
#   'Kaduna': 9,
#   'Kwara': 10,
#   'Nasarawa': 11,
#   'Abia': 12,
#   'Delta': 13,
#   'Akwa Ibom': 14,
#   'Osun': 15,
#   'Ekiti': 16,
#   'Cross River': 17,
#   'Kogi': 18,
#   'Plateau': 19,
#   'Kano': 20,
#   'Katsina': 21,
#   'Bayelsa': 22,
#   'Borno': 23,
#   'Niger': 24}}

# %%
## The categorical dataset has been converted to a numerical columns
for col,mapping in category_label.items():
    df[col] = df[col].map(mapping)

# %% [markdown]
# ## Feature Scaling

# %%
## Since only the price dataset is skewed, Soem operations need to be performed to reduce the skewness of the dataset
df["price_log"] = np.log1p(df["price"])

# %%
new_numerical_columns = df.select_dtypes(include=["number"]).drop(axis=1,columns=["state","town","title","price"])

# %%
skewTable = new_numerical_columns.skew().sort_values(ascending=False).reset_index()
skewTable.columns = ['feature', 'skewness_value']
plt.figure(figsize=(8,4))
plt.barh(skewTable['feature'],skewTable['skewness_value'],color="red")
plt.xlabel("Skewness Value")
plt.ylabel("feature")
plt.gca().invert_yaxis()
plt.show()

# %%
## It can be observed Our price Log oevr came the skewness
# Now model is ready to be used
# Out:
# 0    parking_space
# 1        price_log
# 2         bedrooms
# 3        bathrooms
# 4          toilets
# Name: feature, dtype: object

# %% [markdown]
# ## Model Building and Training

# %%
## Train Test Split
X = df.drop(columns=["price","price_log"])
y = df["price"]
y_log = df["price_log"]

# %%
X = np.asarray(X)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
scaler
# Out:
# StandardScaler()

# %%
## Without y transformation
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.33, random_state=42)

# %%
#with y transformation
X_train_with_log_y, X_test_with_log_y, y_train_log, y_test_log = train_test_split(
    X_scaled, y_log, test_size=0.33, random_state=42)

# %%
len(X_train),len(y_train)
# Out:
# (16298, 16298)

# %% [markdown]
# ### lasso

# %%
## Compare Models: Lasso, LinearRegression, Bayesian Ridge
param_grid_lasso = {"alpha": [1, 10]}
grid_lasso = GridSearchCV(Lasso(), param_grid_lasso,scoring="neg_root_mean_squared_error", cv=5)
grid_lasso.fit(X_train, y_train)
best_lasso = grid_lasso.best_estimator_

lasso_scores = cross_val_score(best_lasso, X_train, y_train, scoring="neg_root_mean_squared_error", cv=5)
lasso_rmse = -np.mean(lasso_scores)
print(f"[Lasso] CV RMSE Y Normal: {lasso_rmse:.4f}")
# Out:
# [Lasso] CV RMSE Y Normal: 9090744428.5794

# %%
param_grid_lasso = {"alpha": [1, 10]}
grid_lasso = GridSearchCV(Lasso(), param_grid_lasso,scoring="neg_root_mean_squared_error", cv=5)
grid_lasso.fit(X_train_with_log_y, y_train_log)
best_lasso = grid_lasso.best_estimator_

lasso_scores = cross_val_score(best_lasso, X_train_with_log_y, y_train_log, scoring="neg_root_mean_squared_error", cv=5)
lasso_rmse = -np.mean(lasso_scores)
print(f"[Lasso] CV RMSE Y Log: {lasso_rmse:.4f}")
# Out:
# [Lasso] CV RMSE Y Log: 1.0631

# %% [markdown]
# ### Linear Regression

# %%
## Compare Models: Lasso, LinearRegression, Bayesian Ridge
lr = LinearRegression()
lr_scores  = cross_val_score(lr, X_train, y_train, scoring="neg_root_mean_squared_error", cv=5)
lr_rmse  = -np.mean(lr_scores)
print(f"[Linear Regression] CV RMSE Y Normal: {lr_rmse:.4f}")
# Out:
# [Linear Regression] CV RMSE Y Normal: 9090744438.9158

# %%
## Compare Models: Lasso, LinearRegression, Bayesian Ridge
lr = LinearRegression()
lr_scores  = cross_val_score(lr, X_train_with_log_y, y_train_log, scoring="neg_root_mean_squared_error", cv=5)
lr_rmse  = -np.mean(lr_scores)
print(f"[Linear Regression] CV RMSE Y Normal: {lr_rmse:.4f}")
# Out:
# [Linear Regression] CV RMSE Y Normal: 0.8547

# %%
lr.fit(X_train_with_log_y,y_train_log)
# Out:
# LinearRegression()

# %% [markdown]
# ### Bayesian Ridge

# %%
param_grid_bayes = {
    "alpha_1":  [1e-6, 1e-5, 1e-4],
    "lambda_1": [1e-6, 1e-5, 1e-4]
}
grid_bayes = GridSearchCV(BayesianRidge(), param_grid_bayes, scoring="neg_root_mean_squared_error", cv=5)
grid_bayes.fit(X_train, y_train)
best_bayes = grid_bayes.best_estimator_

scores_bayes = cross_val_score(best_bayes, X_train, y_train, scoring="neg_root_mean_squared_error", cv=5)
rmse_bayes = -np.mean(scores_bayes)
print(f"[BayesianRidge] CV RMSE: {rmse_bayes:.4f}")
# Out:
# [BayesianRidge] CV RMSE: 8957792815.9941

# %%
param_grid_bayes = {
    "alpha_1":  [1e-6, 1e-5, 1e-4],
    "lambda_1": [1e-6, 1e-5, 1e-4]
}
grid_bayes = GridSearchCV(BayesianRidge(), param_grid_bayes, scoring="neg_root_mean_squared_error", cv=5)
grid_bayes.fit(X_train_with_log_y, y_train_log)
best_bayes = grid_bayes.best_estimator_

scores_bayes = cross_val_score(best_bayes, X_train_with_log_y, y_train_log, scoring="neg_root_mean_squared_error", cv=5)
rmse_bayes = -np.mean(scores_bayes)
print(f"[BayesianRidge] CV RMSE: {rmse_bayes:.4f}")
# Out:
# [BayesianRidge] CV RMSE: 0.8547

# %%
## It can be Observed that the best model is The bayesian Ridge with the transformed log

# %% [markdown]
# ## Performing Inference

# %%
y_pred_bayes = best_bayes.predict(X_test_with_log_y)
y_pred_lr = lr.predict(X_test_with_log_y)
y_pred_lasso = best_lasso.predict(X_test_with_log_y)

# %%
from sklearn.metrics import mean_squared_error
loss_bayes = mean_squared_error(y_pred_bayes, y_test_log)
loss_lr = mean_squared_error(y_pred_lr, y_test_log)
loss_lasso =  mean_squared_error(y_pred_lasso, y_test_log)
print(f"""
        -------------------------------
                BayesianRidge 
        -------------------------------
        {loss_bayes}
        -------------------------------

        -------------------------------
                Linear Regression 
        -------------------------------
        {loss_lr}
        -------------------------------
                Lasso Regression 
        -------------------------------
        {loss_lasso}
      """)
# Out:
#         -------------------------------
#                 BayesianRidge
#         -------------------------------
#         0.6668054719325498
#         -------------------------------
#
#         -------------------------------
#                 Linear Regression
#         -------------------------------
#         0.6667989171206259
#         -------------------------------
#                 Lasso Regression
#         -------------------------------
#         1.0903704043080984

# %%
from sklearn.metrics import root_mean_squared_error
loss_bayes = root_mean_squared_error(y_pred_bayes, y_test_log)
loss_lr = root_mean_squared_error(y_pred_lr, y_test_log)
loss_lasso =  root_mean_squared_error(y_pred_lasso, y_test_log)
print(f"""
        -------------------------------
                BayesianRidge 
        -------------------------------
        {loss_bayes}
        -------------------------------

        -------------------------------
                Linear Regression 
        -------------------------------
        {loss_lr}
        -------------------------------
                Lasso Regression 
        -------------------------------
        {loss_lasso}
      """)
# Out:
#         -------------------------------
#                 BayesianRidge
#         -------------------------------
#         0.816581577022498
#         -------------------------------
#
#         -------------------------------
#                 Linear Regression
#         -------------------------------
#         0.8165775634442977
#         -------------------------------
#                 Lasso Regression
#         -------------------------------
#         681456833.8446841

# %%
## In evaluation , Linear regression has the highest lowest loss using the RMSE matrics

# %%
## It can be seen that the two best models are the bayerisn riddge and the LR model

# %%
df.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'toilets', 'parking_space', 'title', 'town',
#        'state', 'price', 'price_log'],
#       dtype='object')

# %%
X_train[0]
# Out:
# array([-1.17597274, -0.51653203, -0.95932757, -1.45847146,  0.66001218,
#        -0.51953539, -0.16713253])

# %%
category_label

# %%
temp_df.head()
# Out:
#    bedrooms  bathrooms  toilets  parking_space                 title     town  \
# 0       6.0        5.0      5.0            4.0       Detached Duplex  Mabushi
# 1       4.0        5.0      5.0            4.0     Terraced Duplexes  Katampe
# 2       4.0        5.0      5.0            4.0       Detached Duplex    Lekki
# 3       4.0        4.0      5.0            6.0       Detached Duplex     Ajah
# 4       4.0        4.0      5.0            2.0  Semi Detached Duplex    Lekki
#
#    state        price
# 0  Abuja  450000000.0
# 1  Abuja  800000000.0
# 2  Lagos  120000000.0
# 3  Lagos   40000000.0
# 4  Lagos   75000000.0

# %%
def calculate_price(bedrooms,bathrooms,toilets,parking_space,title,town,state):
    title_index = category_label["title"][title]
    town_index = category_label["town"][town]
    state_index = category_label["state"][state]

    features = np.array([bedrooms,bathrooms,toilets,parking_space,title_index,town_index,state_index]).reshape(1,-1)
    feature_scaled = scaler.transform(features)
    prediction = lr.predict(feature_scaled)[0]
    print(feature_scaled)
    # print(np.exp(prediction))
    return np.expm1(prediction)

calculate_price(bedrooms=6,bathrooms=5,toilets=5,parking_space=4,title="Detached Duplex",town="Mabushi",state="Abuja")
# Out:
# [[ 1.45913346  0.34321194 -0.14381868 -0.02980548 -0.70298764 -0.64064834
#   -0.76687673]]
# 195194312.27619904

# %%
np.expm1(lr.predict(X_test_with_log_y[0].reshape(1,-1)))
# Out:
# array([2.09577018e+08])

# %%
np.expm1(y_test_log[0])
# Out:
# 449999999.9999995

# %% [markdown]
# ## Saving Necessary files to build application

# %%
import pickle

# %%
with open('model.pickle', 'wb') as f:
    pickle.dump(lr,f)

# %%
with open('category_indexs.json', 'wb') as f:
    pickle.dump(category_label,f)

# %%
with open('scaler.pickle', 'wb') as f:
    pickle.dump(scaler,f)

# %%
# root_mean_squared_error([np.expm1(lr.predict(X_test_with_log_y[0].reshape(1,-1)))],[np.expm1(y_test_log[0])])
# Out:
# 240422981.75849614

# %%
np.expm1([0.2])
# Out:
# array([0.22140276])

# %%
np.exp([0.2])
# Out:
# array([1.22140276])

# %%
categorical_columns.columns.tolist()
# Out:
# ['title', 'town', 'state']

# %%
state_town_map = categorical_columns.groupby(["state","town"]).sum().index
state_town_map
# Out:
# MultiIndex([(   'Abia',                       'Aba'),
#             (   'Abia',                   'Umuahia'),
#             (  'Abuja',                       'Apo'),
#             (  'Abuja',          'Asokoro District'),
#             (  'Abuja',                     'Bwari'),
#             (  'Abuja', 'Central Business District'),
#             (  'Abuja',                  'Dakibiyu'),
#             (  'Abuja',                     'Dakwo'),
#             (  'Abuja',                      'Dape'),
#             (  'Abuja',                   'Dei-Dei'),
#             ...
#             (    'Oyo',                       'Ido'),
#             (    'Oyo',                   'Oluyole'),
#             (    'Oyo',                  'Oyo West'),
#             ('Plateau',                 'Jos North'),
#             ('Plateau',                 'Jos South'),
#             ( 'Rivers',                     'Eleme'),
#             ( 'Rivers',                   'Ikwerre'),
#             ( 'Rivers',                'Obio-Akpor'),
#             ( 'Rivers',                    'Oyigbo'),
#             ( 'Rivers',             'Port Harcourt')],
#            names=['state', 'town'], length=221)

# %%
state_town_map[2]
# Out:
# ('Abuja', 'Apo')

# %%
state_town_relationship = {}
for (state,town) in state_town_map:
    if state in state_town_relationship:
        state_town_relationship[state].append(town)
    else:
        state_town_relationship[state] = []
        state_town_relationship[state].append(town)

# %%
import json
with open('state_town_relationship.json', 'w') as f:
    json.dump(state_town_relationship,f)

# %%
category_label
# Out:
# {'title': {'Detached Duplex': 0,
#   'Terraced Duplexes': 1,
#   'Semi Detached Duplex': 2,
#   'Detached Bungalow': 3,
#   'Block of Flats': 4,
#   'Semi Detached Bungalow': 5,
#   'Terraced Bungalow': 6},
#  'town': {'Mabushi': 0,
#   'Katampe': 1,
#   'Lekki': 2,
#   'Ajah': 3,
#   'Epe': 4,
#   'Lokogoma District': 5,
#   'Oredo': 6,
#   'Victoria Island (VI)': 7,
#   'Mowe Ofada': 8,
#   'Ikeja': 9,
#   'Ikoyi': 10,
#   'Magodo': 11,
#   'Kaura': 12,
#   'Galadimawa': 13,
#   'Gwarinpa': 14,
#   'Abeokuta North': 15,
#   'Lugbe District': 16,
#   'Ibeju Lekki': 17,
#   'Yaba': 18,
#   'Sango Ota': 19,
#   'Ifako-Ijaiye': 20,
#   'Agege': 21,
#   'Ikorodu': 22,
#   'Jahi': 23,
#   'Ibadan': 24,
#   'Orozo': 25,
#   'Ifo': 26,
#   'Owerri North': 27,
#   'Guzape District': 28,
#   'Idu Industrial': 29,
#   'Owerri Municipal': 30,
#   'Isheri North': 31,
#   'Utako': 32,
#   'Port Harcourt': 33,
#   'Kuje': 34,
#   'Isheri': 35,
#   'Life Camp': 36,
#   'Ipaja': 37,
#   'Ado-Odo/Ota': 38,
#   'Dape': 39,
#   'Mushin': 40,
#   'Ejigbo': 41,
#   'Isolo': 42,
#   'Ojodu': 43,
#   'Gaduwa': 44,
#   'Enugu': 45,
#   'Dakwo': 46,
#   'Asokoro District': 47,
#   'Alimosho': 48,
#   'Sagamu': 49,
#   'Chikun': 50,
#   'Egbeda': 51,
#   'Wuye': 52,
#   'Kubwa': 53,
#   'Shomolu': 54,
#   'Ogudu': 55,
#   'Owerri West': 56,
#   'Ibafo': 57,
#   'Surulere': 58,
#   'Obio-Akpor': 59,
#   'Ayobo': 60,
#   'Apo': 61,
#   'Mowe Town': 62,
#   'Ibadan South-West': 63,
#   'Wuse 2': 64,
#   'Durumi': 65,
#   'Simawa': 66,
#   'Arepo': 67,
#   'Ikotun': 68,
#   'Oluyole': 69,
#   'Maitama District': 70,
#   'Maryland': 71,
#   'Ido': 72,
#   'Karsana': 73,
#   'Wuse': 74,
#   'Ilorin West': 75,
#   'Kurudu': 76,
#   'Karmo': 77,
#   'Abeokuta South': 78,
#   'KM 46': 79,
#   'Gbagada': 80,
#   'Idimu': 81,
#   'Kaduna South': 82,
#   'Magboro': 83,
#   'Gudu': 84,
#   'Kukwaba': 85,
#   'Mbora (Nbora)': 86,
#   'Obafemi Owode': 87,
#   'Jabi': 88,
#   'Karu': 89,
#   'Ojo': 90,
#   'Garki': 91,
#   'Aba': 92,
#   'Ogijo': 93,
#   'Asaba': 94,
#   'Uyo': 95,
#   'Kosofe': 96,
#   'Oyigbo': 97,
#   'Karshi': 98,
#   'Osogbo': 99,
#   'Kado': 100,
#   'Ilupeju': 101,
#   'Afijio': 102,
#   'Ketu': 103,
#   'Ado-Ekiti': 104,
#   'Ibadan North': 105,
#   'Egor': 106,
#   'Nyanya': 107,
#   'Ibarapa North': 108,
#   'Kyami': 109,
#   'Ojota': 110,
#   'Dutse': 111,
#   'Nasarawa': 112,
#   'Calabar': 113,
#   'Kaduna North': 114,
#   'Eleme': 115,
#   'Kafe': 116,
#   'Oshodi': 117,
#   'Dakibiyu': 118,
#   'Amuwo Odofin': 119,
#   'Ijede': 120,
#   'Bwari': 121,
#   'Dekina': 122,
#   'Jos South': 123,
#   'Agbara-Igbesa': 124,
#   'Ijaiye': 125,
#   'Kagini': 126,
#   'Ohaji/Egbema': 127,
#   'Mpape': 128,
#   'Apapa': 129,
#   'Lagos Island': 130,
#   'Gwagwalada': 131,
#   'Ijoko': 132,
#   'Diplomatic Zones': 133,
#   'Akure': 134,
#   'Ethiope West': 135,
#   'Badagry': 136,
#   'Kano': 137,
#   'Ede South': 138,
#   'Ilorin South': 139,
#   'Oke-Aro': 140,
#   'Oke-Odo': 141,
#   'Ikot Ekpene': 142,
#   'Kusada': 143,
#   'Akinyele': 144,
#   'Kabusa': 145,
#   'Dei-Dei': 146,
#   'Eket': 147,
#   'Egbe': 148,
#   'Udu': 149,
#   'Ibadan North-East': 150,
#   'Danja': 151,
#   'Yewa South': 152,
#   'Warri': 153,
#   'Duboyi': 154,
#   'Jikwoyi': 155,
#   'Oyo West': 156,
#   'Agbara': 157,
#   'Ovia North-East': 158,
#   'Yenagoa': 159,
#   'Central Business District': 160,
#   'Guzamala': 161,
#   'Lokoja': 162,
#   'Jos North': 163,
#   'Orile': 164,
#   'Wumba': 165,
#   'Ibadan North-West': 166,
#   'Eko Atlantic City': 167,
#   'Imota': 168,
#   'Ikwerre': 169,
#   'Keffi': 170,
#   'Ilorin East': 171,
#   'Uvwie': 172,
#   'Umuahia': 173,
#   'Ijesha': 174,
#   'Okene': 175,
#   'Aniocha South': 176,
#   'Ijebu Ode': 177,
#   'Okpe': 178,
#   'Ughelli South': 179,
#   'Ewekoro': 180,
#   'Nassarawa': 181,
#   'Mararaba': 182,
#   'Uhunmwonde': 183,
#   'Ughelli North': 184,
#   'Ibeju': 185,
#   'Abraka': 186,
#   'Paikoro': 187,
#   'Ikpoba Okha': 188},
#  'state': {'Abuja': 0,
#   'Lagos': 1,
#   'Edo': 2,
#   'Ogun': 3,
#   'Oyo': 4,
#   'Imo': 5,
#   'Anambara': 6,
#   'Rivers': 7,
#   'Enugu': 8,
#   'Kaduna': 9,
#   'Kwara': 10,
#   'Nasarawa': 11,
#   'Abia': 12,
#   'Delta': 13,
#   'Akwa Ibom': 14,
#   'Osun': 15,
#   'Ekiti': 16,
#   'Cross River': 17,
#   'Kogi': 18,
#   'Plateau': 19,
#   'Kano': 20,
#   'Katsina': 21,
#   'Bayelsa': 22,
#   'Borno': 23,
#   'Niger': 24}}
